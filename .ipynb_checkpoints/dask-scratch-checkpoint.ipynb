# %%
import dask.dataframe as dd
import dask.array as da
import dask
import numpy as np
import scipy as sp
from scipy import stats
import matplotlib.pyplot as plt
import time

# %%
s = 100000
L = 100000000
a = np.arange(L)
big = np.zeros(s)

# %%
# big = np.zeros(s)
for N in range(5):
    big = np.zeros(s)
    n = 10**N
    start = time.time()
    print(n," chunks\nremainder",s%n)
    for i in range(n):
        big[s//n*i:s//n*(i+1)] = np.random.choice(a[int(L/n*i):int(L/n*(i+1))], s//n, replace=True)
    print((time.time()-start)*10//10," seconds\n---")
    plt.plot(big)
    plt.show()
# Out:
# 1  chunks
# remainder 0
# 0.0  seconds
# ---
# 10  chunks
# remainder 0
# 0.0  seconds
# ---
# 100  chunks
# remainder 0
# 0.0  seconds
# ---
# 1000  chunks
# remainder 0
# 0.0  seconds
# ---
# 10000  chunks
# remainder 0
# 0.0  seconds
# ---

# %%
# %%timeit
if n < 10000:
    0
    if n > 1000:
        0
# Out:
# 37.6 ns ± 2.07 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
times = np.zeros((20,3))
times[0] = [1, 1170, 342]
times[1] = [2, 946, 220]
times[2] = [4, 902, 196]
times[3] = [8, 847, 212]
times[4] = [16, 718, 179]
times[5] = [32, 771, 265]
times[6] = [64, 482, 191]
times[7] = [256, 280, 52.7]
times[8] = [1024, 361, 71.5]

# %%
L = 10000000
Max = 10000
s=np.arange(L)
plt.plot((L-Max)//(s+1))
plt.yscale('log')
plt.xscale('log')

# %%
(25-np.array([17,1,2,3,4,5,6])-1)/(5-1)
# Out:
# array([1.75, 5.75, 5.5 , 5.25, 5.  , 4.75, 4.5 ])

# %%
arr0 = dd.read_csv('../dmpc/r1/pressure-tensor.xvg', skiprows = 33, header=None, delim_whitespace=True, sample=3300000)

# %%
arr0.head()
# Out:
#     0           1           2           3           4           5   \
# 0  0.0  311.097290   59.331459  -45.010242   18.823420  -44.083313
# 1  2.0  311.226868  -52.248123  -16.772848  -99.244408  -17.765566
# 2  4.0  311.587463 -230.264603   63.565117  -10.174314   61.410522
# 3  6.0  312.801849  182.588135 -162.219559  -28.434866 -160.977158
# 4  8.0  310.813446   91.957085 -104.257111  110.495293 -104.638176
#
#            6           7           8           9           10
# 0   35.282639  316.700134   20.125151  315.188049   56.849167
# 1  204.537720  -16.148245 -100.923302  -15.057701  191.339890
# 2   39.967865   25.077406  -10.532000   26.330414  297.512329
# 3  -23.008495   -9.890800  -28.224962  -11.505493   39.299557
# 4  151.074554 -132.606369  109.375931 -133.124130    9.941408

# %%
arr0.columns = ['t','temp','xx','xy','xz','yx','yy','yz','zx','zy','zz']

# %%
np.array(arr0['xy'])
# Out:
# array([-45.010242, -16.772848,  63.565117, ...,  -1.923454,  29.787161,
#        143.516693])

# %%
arr0.head()
# Out:
#      t        temp          xx          xy          xz          yx  \
# 0  0.0  311.097290   59.331459  -45.010242   18.823420  -44.083313
# 1  2.0  311.226868  -52.248123  -16.772848  -99.244408  -17.765566
# 2  4.0  311.587463 -230.264603   63.565117  -10.174314   61.410522
# 3  6.0  312.801849  182.588135 -162.219559  -28.434866 -160.977158
# 4  8.0  310.813446   91.957085 -104.257111  110.495293 -104.638176
#
#            yy          yz          zx          zy          zz
# 0   35.282639  316.700134   20.125151  315.188049   56.849167
# 1  204.537720  -16.148245 -100.923302  -15.057701  191.339890
# 2   39.967865   25.077406  -10.532000   26.330414  297.512329
# 3  -23.008495   -9.890800  -28.224962  -11.505493   39.299557
# 4  151.074554 -132.606369  109.375931 -133.124130    9.941408

# %%
arr0.t.loc[0].compute()
# Out:
# 0    0.0
# Name: t, dtype: float64

# %%
(arr0['xx'].loc[0].values-arr0['xx'].loc[1].values).compute()[0]
# Out:
# 111.57958199999999

# %%
arr0.loc[10,'temp'].compute()-arr0.loc[11,'temp'].compute()
# Out:
# 10   NaN
# 11   NaN
# Name: temp, dtype: float64

# %%
arr0['temp'].sem()/arr0['temp'].size
# Out:
# dd.Scalar<truediv..., dtype=float64>

# %%
arr0[['xy','yx']].mean(axis=1).compute()
# Out:
# 0        -44.546778
# 1        -17.269207
# 2         62.487820
# 3       -161.598359
# 4       -104.447643
#             ...
# 97996     -8.141260
# 97997    224.192101
# 97998     -0.709892
# 97999     28.923315
# 98000    143.557266
# Length: 98001, dtype: float64

# %%
np.zeros_like(arr0.xy)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
len(arr0.xy)
# Out:
# 98001

# %%
arr0.xy
# Out:
# Dask Series Structure:
# npartitions=1
#     float64
#         ...
# Name: xy, dtype: float64
# Dask Name: getitem, 3 tasks

# %%
cheese = arr0[['xy','yx']].mean(axis=1)

# %%
cheese
# Out:
# Dask Series Structure:
# npartitions=1
#     float64
#         ...
# dtype: float64
# Dask Name: dataframe-mean, 4 tasks

# %%
cheese.compute()
# Out:
# 0        -44.546778
# 1        -17.269207
# 2         62.487820
# 3       -161.598359
# 4       -104.447643
#             ...
# 97996     -8.141260
# 97997    224.192101
# 97998     -0.709892
# 97999     28.923315
# 98000    143.557266
# Length: 98001, dtype: float64

# %%
cheese -= cheese.mean()

# %%
cheese.compute()
# Out:
# 0        -44.400124
# 1        -17.122554
# 2         62.634473
# 3       -161.451705
# 4       -104.300990
#             ...
# 97996     -7.994606
# 97997    224.338754
# 97998     -0.563239
# 97999     29.069968
# 98000    143.703919
# Length: 98001, dtype: float64

# %%
cheese.mean().compute()
# Out:
# 8.445221769301994e-16

# %%
bigpressure = arr0

# %%
bigpressure["temp"].mean().compute()
# Out:
# 312.0143459276844

# %%
bigpressure["temp"].sem().compute()
# Out:
# 0.003500619172192214

# %%
stress = cheese

# %%
len(stress)
# Out:
# 98001

# %%
sa = np.zeros_like(stress)

# %%
plt.plot(sa)
plt.ylim(-0.01,0.01)
plt.xlim(0,1000)
# Out:
# (0.0, 1000.0)

# %%
def autocor(arr, tau):
    if tau > len(arr):
        return "tau set too large"
    aaa = arr.loc[tau:].values * arr.loc[:len(stress) - tau - 1].values
    # if tau % 100 == 0:
    #     print(f"\r{(tau/len(arr))*100:6.2f}", "%   ", end="")
    return(aaa.mean().compute(),((aaa.var()/(len(arr)-tau))**0.5).compute())
autocor(stress,0)
# Out:
# (9444.811660708287, 42.5515973875807)

# %%
tau=4000
(stress.loc[tau:].values * stress.loc[:len(stress)-tau-1].values).compute()
# [(stress.loc[10].values * stress.loc[10 + 4000].values) for i in range(len(stress) - 4000)].mean()
# autocor(stress,1)
# (stress.loc[1].values*stress.loc[12].values).compute()
# Out:
# array([ 8.36110176e+03,  2.80434203e+03,  1.17578228e+03, ...,
#        -9.83831909e-01, -1.27066595e+03, -1.25489370e+04])

# %%
stress.loc[4000:].mul(stress.loc[:len(stress)-4000-1]).compute()
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 97996   NaN
# 97997   NaN
# 97998   NaN
# 97999   NaN
# 98000   NaN
# Length: 98001, dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-d1dd9a877fc7> in <module>
# ----> 1 print(len(test[5:]))
#       2 print(len(test[:len(test)-5]))
#
# NameError: name 'test' is not defined

# %%
def autocor(arr, tau):
#     print(tau)
#     if tau > len(arr):
#         print("tau ", tau, "    lenarr ", len(arr))
#         return "tau set too large"
    aaa = np.array(arr.loc[tau:].values) * np.array(arr.loc[:len(arr) - tau - 1].values)
    if tau % 1 == 0:
        print(tau/len(arr))
    return(aaa.mean(),((aaa.var()/(len(arr)-tau))**0.5))

# %%
stress_autocor = sp.zeros((len(stress)-1, 2))
for tau in range(len(stress)-1):
    stress_autocor[tau] = autocor(stress, tau)
# Out:
# <ipython-input-178-292029400d06>:1: DeprecationWarning: scipy.zeros is deprecated and will be removed in SciPy 2.0.0, use numpy.zeros instead
#   stress_autocor = sp.zeros((len(stress)-1, 2))
# 0.0
# 1.0203977510433567e-05
# 2.0407955020867133e-05
# 3.06119325313007e-05
# 4.0815910041734266e-05
# 5.1019887552167836e-05
# 6.12238650626014e-05
# 7.142784257303498e-05
# 8.163182008346853e-05
# 9.18357975939021e-05
# 0.00010203977510433567
# 0.00011224375261476924
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-178-292029400d06> in <module>
#       1 stress_autocor = sp.zeros((len(stress)-1, 2))
#       2 for tau in range(len(stress)-1):
# ----> 3     stress_autocor[tau] = autocor(stress, tau)
#
# <ipython-input-177-c61fddea8ea0> in autocor(arr, tau)
#       4 #         print("tau ", tau, "    lenarr ", len(arr))
#       5 #         return "tau set too large"
# ----> 6     aaa = np.array(arr.loc[tau:].values) * np.array(arr.loc[:len(arr) - tau - 1].values)
#       7     if tau % 1 == 0:
#       8         print(tau/len(arr))
#
# /usr/local/anaconda3/lib/python3.8/site-packages/dask/array/core.py in __array__(self, dtype, **kwargs)
#    1338
#    1339     def __array__(self, dtype=None, **kwargs):
# -> 1340         x = self.compute()
#    1341         if dtype and x.dtype != dtype:
#    1342             x = x.astype(dtype)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/dask/base.py in compute(self, **kwargs)
#     164         dask.base.compute
#     165         """
# --> 166         (result,) = compute(self, traverse=False, **kwargs)
#     167         return result
#     168
#
# /usr/local/anaconda3/lib/python3.8/site-packages/dask/base.py in compute(*args, **kwargs)
#     442         postcomputes.append(x.__dask_postcompute__())
#     443
# --> 444     results = schedule(dsk, keys, **kwargs)
#     445     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     446
#
# /usr/local/anaconda3/lib/python3.8/site-packages/dask/threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      74                 pools[thread][num_workers] = pool
#      75
# ---> 76     results = get_async(
#      77         pool.apply_async,
#      78         len(pool._pool),
#
# /usr/local/anaconda3/lib/python3.8/site-packages/dask/local.py in get_async(apply_async, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, **kwargs)
#     473             # Main loop, wait on tasks to finish, insert new ones
#     474             while state["waiting"] or state["ready"] or state["running"]:
# --> 475                 key, res_info, failed = queue_get(queue)
#     476                 if failed:
#     477                     exc, tb = loads(res_info)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/dask/local.py in queue_get(q)
#     131
#     132     def queue_get(q):
# --> 133         return q.get()
#     134
#     135
#
# /usr/local/anaconda3/lib/python3.8/queue.py in get(self, block, timeout)
#     168             elif timeout is None:
#     169                 while not self._qsize():
# --> 170                     self.not_empty.wait()
#     171             elif timeout < 0:
#     172                 raise ValueError("'timeout' must be a non-negative number")
#
# /usr/local/anaconda3/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
Max=10
def autocor_full(arr):
#     arr = arr_in.to_dask_array(lengths=True)
    autocor = sp.zeros(Len-2*Max+1)
    autocor_unc = sp.zeros(Len-2*Max+1)
    for tau in range(Len-2*Max+1):
        if tau % 1 == 0:
            print(tau/(Len-2*Max+1))
        skip = (Len-tau-1)//(Max-2)
        one = arr.loc[::skip]
        two = arr.shift(tau).loc[::skip]
        temp = one.mul(two).dropna()
        autocor[tau] = temp.mean().compute()
        autocor_unc[tau] = temp.sem(split_every=2).compute()
#     print(Len-2*Max+1, 'of', Len-Min)
#     for tau in range(Len-2*Max+1, Len-Max):
#         temp = np.array([arr[i]*arr[i+tau] for i in np.arange(0, Max)])
#         autocor[tau] = np.mean(temp)
#         autocor_unc[tau] = np.sem(temp)
#     print(Len-Max, 'of', Len-Min)
#     for tau in range(Len-Max, Len-Min):
#         temp = np.array([arr[i]*arr[i+tau] for i in np.arange(0, Len-Min)])
#         autocor[tau] = np.mean(temp)
#         autocor_unc[tau] = np.sem(tep)

# %%
Len=len(stress)
print(Len)
Max = 1000
autocor_full(stress)
# Out:
# 98001
# 0.0
# <ipython-input-211-87fec4f7819b>:4: DeprecationWarning: scipy.zeros is deprecated and will be removed in SciPy 2.0.0, use numpy.zeros instead
#   autocor = sp.zeros(Len-2*Max+1)
# <ipython-input-211-87fec4f7819b>:5: DeprecationWarning: scipy.zeros is deprecated and will be removed in SciPy 2.0.0, use numpy.zeros instead
#   autocor_unc = sp.zeros(Len-2*Max+1)
# 1.0416449657298807e-05
# 2.0832899314597614e-05
# 3.1249348971896416e-05
# 4.166579862919523e-05
# 5.208224828649403e-05
# 6.249869794379283e-05
# 7.291514760109164e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-212-4ab86e25f3b5> in <module>
#       2 print(Len)
#       3 Max = 1000
# ----> 4 autocor_full(stress)
#
# <ipython-input-211-87fec4f7819b> in autocor_full(arr)
#      11         two = arr.shift(tau).loc[::skip]
#      12         temp = one.mul(two).dropna()
# ---> 13         autocor[tau] = temp.mean().compute()
#      14         autocor_unc[tau] = temp.sem(split_every=2).compute()
#      15 #     print(Len-2*Max+1, 'of', Len-Min)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/dask/base.py in compute(self, **kwargs)
#     164         dask.base.compute
#     165         """
# --> 166         (result,) = compute(self, traverse=False, **kwargs)
#     167         return result
#     168
#
# /usr/local/anaconda3/lib/python3.8/site-packages/dask/base.py in compute(*args, **kwargs)
#     442         postcomputes.append(x.__dask_postcompute__())
#     443
# --> 444     results = schedule(dsk, keys, **kwargs)
#     445     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     446
#
# /usr/local/anaconda3/lib/python3.8/site-packages/dask/threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      74                 pools[thread][num_workers] = pool
#      75
# ---> 76     results = get_async(
#      77         pool.apply_async,
#      78         len(pool._pool),
#
# /usr/local/anaconda3/lib/python3.8/site-packages/dask/local.py in get_async(apply_async, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, **kwargs)
#     473             # Main loop, wait on tasks to finish, insert new ones
#     474             while state["waiting"] or state["ready"] or state["running"]:
# --> 475                 key, res_info, failed = queue_get(queue)
#     476                 if failed:
#     477                     exc, tb = loads(res_info)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/dask/local.py in queue_get(q)
#     131
#     132     def queue_get(q):
# --> 133         return q.get()
#     134
#     135
#
# /usr/local/anaconda3/lib/python3.8/queue.py in get(self, block, timeout)
#     168             elif timeout is None:
#     169                 while not self._qsize():
# --> 170                     self.not_empty.wait()
#     171             elif timeout < 0:
#     172                 raise ValueError("'timeout' must be a non-negative number")
#
# /usr/local/anaconda3/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
stress.shift(2).dropna().loc[::-10].compute()
# Out:
# 98000     -0.563239
# 97990   -115.063685
# 97980    -40.185841
# 97970     21.746808
# 97960    181.473740
#             ...
# 140       18.471122
# 130      -35.768331
# 120      -16.332455
# 110      -23.997686
# 100       18.600166
# Length: 9791, dtype: float64

# %%
tau = 2
skip = (Len-tau-1)//(Max-2)

# %%
# %%timeit
one = stress.shift(2).loc[::10]
two = stress.loc[::10]
one.mul(two).dropna().mean().compute()
# Out:
# 206 ms ± 18.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit

stress.mul(stress.shift(2)).dropna().loc[::10].mean().compute()
# Out:
# 199 ms ± 14.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
stress.to_dask_array(lengths=True)[1].mean()
# Out:
# dask.array<mean_agg-aggregate, shape=(), dtype=float64, chunksize=(), chunktype=numpy.ndarray>

# %%
# Out:
# 0    -44.400124
# 1    -17.122554
# 2     62.634473
# 3   -161.451705
# 4   -104.300990
# dtype: float64

# %%
dask.array([1234,3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-379-27674b5d499b> in <module>
# ----> 1 dask.array([1234,3])
#
# TypeError: 'module' object is not callable

# %%
stress.to_dask_array()
# Out:
# dask.array<values, shape=(nan,), dtype=float64, chunksize=(nan,), chunktype=numpy.ndarray>
