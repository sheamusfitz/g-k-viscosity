# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
from scipy import stats

# %%
lengths = ['1', '40', '79', '118', '157', '196']
widths = ['8', '12', '15']

# %%
viscos = pd.DataFrame()
for ns in lengths:
    for w in widths:
        for i in range(1,6):
            viscos[f'{w}nm-{ns}ns-r{i}-visc'] = pd.Series(np.load(f'../dmpc-{w}nm/r{i}/{ns}ns_sim.npz', 
                                                     allow_pickle=True)['arr_3'])
    viscos[f'{ns}ns-time'] = pd.Series(np.load(f'../dmpc-8nm/r1/{ns}ns_sim.npz',
                                                 allow_pickle=True)['arr_1'])

# %%
viscos.head()
# Out:
#    8nm-1ns-r1-visc  8nm-1ns-r2-visc  8nm-1ns-r3-visc  8nm-1ns-r4-visc  \
# 0     2.265770e-13     2.287890e-13     2.283271e-13     2.295271e-13
# 1     4.391832e-13     4.437002e-13     4.428042e-13     4.450223e-13
# 2     6.133900e-13     6.204476e-13     6.192322e-13     6.219797e-13
# 3     7.338827e-13     7.437457e-13     7.424830e-13     7.451119e-13
# 4     7.968528e-13     8.096805e-13     8.088480e-13     8.107454e-13
#
#    8nm-1ns-r5-visc  12nm-1ns-r1-visc  12nm-1ns-r2-visc  12nm-1ns-r3-visc  \
# 0     2.290353e-13      1.689744e-13      1.681697e-13      1.676619e-13
# 1     4.440964e-13      3.288585e-13      3.272810e-13      3.263883e-13
# 2     6.207540e-13      4.637431e-13      4.614713e-13      4.605358e-13
# 3     7.437066e-13      5.635706e-13      5.606841e-13      5.601968e-13
# 4     8.091691e-13      6.256786e-13      6.222091e-13      6.227105e-13
#
#    12nm-1ns-r4-visc  12nm-1ns-r5-visc  ...  12nm-196ns-r2-visc  \
# 0      1.668372e-13      1.681055e-13  ...        1.679309e-13
# 1      3.246988e-13      3.271718e-13  ...        1.210275e-12
# 2      4.578829e-13      4.613687e-13  ...        1.554711e-12
# 3      5.564796e-13      5.606564e-13  ...        1.780860e-12
# 4      6.178913e-13      6.223171e-13  ...        1.984701e-12
#
#    12nm-196ns-r3-visc  12nm-196ns-r4-visc  12nm-196ns-r5-visc  \
# 0        1.677919e-13        1.678055e-13        1.678312e-13
# 1        1.211114e-12        1.206802e-12        1.215137e-12
# 2        1.558215e-12        1.552048e-12        1.565463e-12
# 3        1.787014e-12        1.778866e-12        1.796086e-12
# 4        1.992473e-12        1.980853e-12        2.002375e-12
#
#    15nm-196ns-r1-visc  15nm-196ns-r2-visc  15nm-196ns-r3-visc  \
# 0        1.540317e-13        1.539882e-13        1.538686e-13
# 1        1.159998e-12        1.162240e-12        1.159913e-12
# 2        1.480792e-12        1.482466e-12        1.480534e-12
# 3        1.688283e-12        1.688143e-12        1.683598e-12
# 4        1.871159e-12        1.870405e-12        1.865549e-12
#
#    15nm-196ns-r4-visc  15nm-196ns-r5-visc  196ns-time
# 0        1.539692e-13        1.540706e-13       0.000
# 1        1.159598e-12        1.159224e-12       0.196
# 2        1.479592e-12        1.478429e-12       0.392
# 3        1.684340e-12        1.682745e-12       0.588
# 4        1.865749e-12        1.863451e-12       0.784
#
# [5 rows x 96 columns]

# %%
for w in widths:
    for ns in lengths:
        viscos[f'{w}nm-{ns}ns-mean'] = np.mean(
            [viscos[f'{w}nm-{ns}ns-r{i}-visc'] for i in range(1,6)],
            axis=0
        )

# %%
viscos['8nm-196ns-mean']
# Out:
# 0         2.284386e-13
# 1         1.426635e-12
# 2         1.894045e-12
# 3         2.226204e-12
# 4         2.538512e-12
#               ...
# 499995   -1.509228e-11
# 499996   -1.509050e-11
# 499997   -1.508821e-11
# 499998   -1.508479e-11
# 499999   -1.508384e-11
# Name: 8nm-196ns-mean, Length: 500000, dtype: float64

# %%
plt.figure(figsize=(15,7))
for w in widths:
    plt.plot(viscos[f'196ns-time']/1000, viscos[f'{w}nm-196ns-mean'])
plt.ylim(0,8e-11)
plt.axvline(3, c='r')
plt.axvline(12, c='r')

# %%
plt.figure(figsize=(15,7))
for w in widths:
    plt.plot(viscos[f'196ns-time']/1000, viscos[f'{w}nm-196ns-mean'])
plt.ylim(0,8e-11)
plt.xlim(0,15)
plt.axvline(3, c='r')
plt.axvline(12, c='r')

# %%
for w in widths:
    plt.figure(figsize=(15,7))
    for c, ns in enumerate(lengths):
        plt.plot(viscos[f'{ns}ns-time']/1000, viscos[f'{w}nm-{ns}ns-mean'],
                 c = plt.cm.Blues(plt.Normalize(0,5)(c)), linewidth=5)
    plt.colorbar(plt.cm.ScalarMappable(norm=plt.Normalize(0,196), cmap = 'Blues'))
    plt.ylim(0,8e-11)
#     plt.xlim(0,10)
    plt.ylim(0,8e-11)
    plt.xlim(0,20)
    plt.axvline(3, c='r')
    plt.axvline(12, c='r')
    plt.show()

# %%
for w in widths:
    plt.figure(figsize=(15,7))
    for c, ns in enumerate(lengths):
        plt.plot(viscos[f'{ns}ns-time']/1000, viscos[f'{w}nm-{ns}ns-mean'],
                 c = plt.cm.Blues(plt.Normalize(80,196)(int(ns))), linewidth=5)
    plt.colorbar(plt.cm.ScalarMappable(norm=plt.Normalize(80,196), cmap = 'Blues'))
    plt.ylim(0,8e-11)
#     plt.xlim(0,10)
    plt.ylim(0,8e-11)
    plt.xlim(0,20)
    plt.axvline(3, c='r')
    plt.axvline(12, c='r')
    plt.show()

# %%
for c, w in enumerate(widths):
    plt.figure(figsize=(6,3))
    for ns in lengths[1:]:
        x = float(ns)
        y = np.mean(viscos[f'{w}nm-{ns}ns-mean'][3000//int(ns):12000//int(ns)])
        yerr = float(sp.stats.sem(viscos[f'{w}nm-{ns}ns-mean'][3000//int(ns):12000//int(ns)]))
        plt.errorbar(x = x, y = y, yerr = yerr, marker='.', ms=12, c=f'C{c}')
    plt.show()

# %%
plt.figure(figsize=(12,7))
for c, ns in enumerate(lengths):
    plt.plot(viscos[f'{ns}-time']/1000, viscos[f'{ns}-visc'], c = plt.cm.Reds(plt.Normalize(0,5)(c)), linewidth=3)
plt.ylim(2e-11, 8e-11)
plt.xlim(1e-1, 10)

plt.yscale('log')
plt.xscale('log')

# %%
plt.figure(figsize=(12,7))
for c, ns in enumerate(lengths):
    plt.plot(viscos[f'{ns}-time'], viscos[f'{ns}-auto'], c = plt.cm.Reds(plt.Normalize(0,6)(c)), linewidth=c)
plt.ylim(-1000,4000)
# plt.yscale('symlog')
# plt.yscale('log')
plt.xlim(np.array([-0.1,1])*2)

# plt.yscale('symlog')
# plt.xscale('log')
# Out:
# (-0.2, 2.0)
